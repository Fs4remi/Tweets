# %%
import pandas as pd
import datetime
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as ptk

from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB       
from sklearn import metrics

from textblob import TextBlob

sns.set(style="whitegrid")
# %matplotlib inline

plt.rcParams['figure.figsize'] = (16, 6)
plt.rcParams['font.size'] = 18
plt.style.use("fivethirtyeight")
sns.set(style="whitegrid")

# %%
df = pd.read_csv('./original_tweets_corpes.csv')
df['tweet_dates']= pd.to_datetime(df['tweet_dates'], errors = 'coerce')

# %%
df.sample(n=6)
# Out:
#                     source                                               text  \
# 31727   Twitter for iPhone  Such a wonderful statement from the great @Lou...
# 15330   Twitter Web Client  Always bear in mind that your own resolution t...
# 19601  Twitter for Android  "@gmar916: #CelebApprentice @realDonaldTrump N...
# 8640    Twitter Web Client  Pres. Obama is meeting with China’s Pres. this...
# 30345  Twitter for Android  Maybe the millions of people who voted to MAKE...
# 31524   Twitter for iPhone  Thank you to Doug Parker and American Airlines...
#
#        retweet_count  favorite_count  is_retweet         tweet_dates
# 31727        16039.0         68504.0       False 2017-10-14 01:31:20
# 15330          347.0           309.0       False 2014-07-03 18:39:18
# 19601           34.0           106.0       False 2015-02-03 02:06:59
# 8640            86.0            36.0       False 2013-06-03 19:52:00
# 30345        34603.0        158646.0       False 2017-02-25 12:25:24
# 31524        13534.0         78605.0       False 2017-09-22 17:54:59

# %%
df["favorite_count"].describe()
# Out:
# count     37980.000000
# mean      21384.119089
# std       41483.285115
# min           0.000000
# 25%          27.000000
# 50%         174.000000
# 75%       18488.250000
# max      880618.000000
# Name: favorite_count, dtype: float64

# %%
annual_median = df.groupby(by=df["tweet_dates"].dt.year)["favorite_count"].median()
df["fave_count_adj"] = df["favorite_count"] / annual_median[df["tweet_dates"].dt.year.values].values

# %%
df["fave_count_adj"].describe()
# Out:
# count    37980.000000
# mean         4.175094
# std         45.998914
# min          0.000000
# 25%          0.489796
# 50%          1.000000
# 75%          2.237815
# max       3813.115385
# Name: fave_count_adj, dtype: float64

# %%
df['fave_count_adj'].clip(upper=5.0).hist()

# %%
cuts = [-1, 1, 5, np.inf]
engage_category = ['low', 'med', 'high']
df['engagement'] = pd.cut(df['fave_count_adj'].values, bins = cuts, labels = engage_category)

# %%
df.head()
# Out:
#                source                                               text  \
# 0  Twitter Web Client  Be sure to tune in and watch Donald Trump on L...
# 1  Twitter Web Client  Donald Trump will be appearing on The View tom...
# 2  Twitter Web Client  Donald Trump reads Top Ten Financial Tips on L...
# 3  Twitter Web Client  New Blog Post: Celebrity Apprentice Finale and...
# 4  Twitter Web Client  "My persona will never be that of a wallflower...
#
#    retweet_count  favorite_count  is_retweet         tweet_dates  \
# 0          253.0           202.0       False 2009-05-04 18:54:25
# 1            2.0             3.0       False 2009-05-05 01:00:10
# 2            3.0             2.0       False 2009-05-08 13:38:08
# 3            8.0            27.0       False 2009-05-08 20:40:15
# 4         1421.0          1950.0       False 2009-05-12 14:07:28
#
#    fave_count_adj engagement
# 0       31.076923       high
# 1        0.461538        low
# 2        0.307692        low
# 3        4.153846        med
# 4      300.000000       high

# %%
df['engagement'].value_counts()
# Out:
# low     19115
# med     13163
# high     5702
# Name: engagement, dtype: int64

# %%
low_class = 19115

# %% [markdown]
# ## Naive Bayes Classification Model

# %%
X = df['text']
y = df['engagement']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state= 4)
vect = CountVectorizer(lowercase = True)
X_train_dtm = vect.fit_transform(X_train)
X_test_dtm = vect.transform(X_test)
nb = MultinomialNB()
nb.fit(X_train_dtm, y_train)
y_pred_class = nb.predict(X_test_dtm)
NB_CV_accuracy = metrics.accuracy_score(y_test, y_pred_class)
X_train_dtm.shape
# Out:
# (28485, 29477)

# %%
print("Baseline accuracy is {}%".format((low_class / 37980) * 100))
print("Using NB model accuracy is {}%".format(NB_CV_accuracy * 100))
# Out:
# Baseline accuracy is 50.3291205897841%
# Using NB model accuracy is 60.400210637177466%

# %%
#Using TfidVectorizer() which normalizes the matrix values
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state= 4)
vect_TFID = TfidfVectorizer(lowercase = True)
X_train_dtm = vect_TFID.fit_transform(X_train)
X_test_dtm = vect_TFID.transform(X_test)
nb = MultinomialNB()
nb.fit(X_train_dtm, y_train)
y_pred_class = nb.predict(X_test_dtm)
NB_TFI_accuracy = metrics.accuracy_score(y_test, y_pred_class)
X_train_dtm.shape
# Out:
# (28485, 29477)

# %%
print("Baseline accuracy is {}%".format((low_class / 37980) * 100))
print("Using NB model accuracy is {}%".format(NB_CV_accuracy * 100))
print("Using NB model using the TfidVectorizer accuracy is {}%".format(NB_TFI_accuracy * 100))
# Out:
# Baseline accuracy is 50.3291205897841%
# Using NB model accuracy is 60.400210637177466%
# Using NB model using the TfidVectorizer accuracy is 58.75724065297525%

# %% [markdown]
# ## Modifying the parameters of countvectorizer
# I printed the number of features each X_train_dtm collects everytime I change a parameter of CountVectorizer() to show a corrolation between higher number of features and accuracy
# ## stop_words

# %%
#string {‘english’}
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state= 4)
vect = CountVectorizer(lowercase = True, stop_words = 'english')
X_train_dtm = vect.fit_transform(X_train)
X_test_dtm = vect.transform(X_test)
nb = MultinomialNB()
nb.fit(X_train_dtm, y_train)
y_pred_class = nb.predict(X_test_dtm)
print("Accuracy: ",metrics.accuracy_score(y_test, y_pred_class)*100)
X_train_dtm.shape
# Out:
# Accuracy:  61.15850447604002
# (28485, 29182)

# %% [markdown]
# ## min_df + stop_words

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state= 4)
vect = CountVectorizer(lowercase = True, stop_words = 'english', min_df = 2)
X_train_dtm = vect.fit_transform(X_train)
X_test_dtm = vect.transform(X_test)
nb = MultinomialNB()
nb.fit(X_train_dtm, y_train)
y_pred_class = nb.predict(X_test_dtm)
print("Accuracy: ",metrics.accuracy_score(y_test, y_pred_class)*100)
X_train_dtm.shape
# Out:
# Accuracy:  61.116377040547654
# (28485, 12662)

# %% [markdown]
# ## min_df alone doesn't improve performance

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state= 4)
vect = CountVectorizer(lowercase = True, min_df = 2)
X_train_dtm = vect.fit_transform(X_train)
X_test_dtm = vect.transform(X_test)
nb = MultinomialNB()
nb.fit(X_train_dtm, y_train)
y_pred_class = nb.predict(X_test_dtm)
print("Accuracy: ",metrics.accuracy_score(y_test, y_pred_class)*100)
X_train_dtm.shape
# Out:
# Accuracy:  60.90573986308584
# (28485, 12949)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state= 4)
vect = CountVectorizer(lowercase = True, min_df = 4)
X_train_dtm = vect.fit_transform(X_train)
X_test_dtm = vect.transform(X_test)
nb = MultinomialNB()
nb.fit(X_train_dtm, y_train)
y_pred_class = nb.predict(X_test_dtm)
print("Accuracy: ",metrics.accuracy_score(y_test, y_pred_class)*100)
X_train_dtm.shape
# Out:
# Accuracy:  60.684570826750914
# (28485, 7406)

# %% [markdown]
# ## ngram_range

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state= 4)
vect = CountVectorizer(lowercase = True, ngram_range=(1,2))
X_train_dtm = vect.fit_transform(X_train)
X_test_dtm = vect.transform(X_test)
nb = MultinomialNB()
nb.fit(X_train_dtm, y_train)
y_pred_class = nb.predict(X_test_dtm)
print("Accuracy: ",metrics.accuracy_score(y_test, y_pred_class)*100)
X_train_dtm.shape
# Out:
# Accuracy:  60.516061084781455
# (28485, 233678)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state= 4)
vect = CountVectorizer(lowercase = True, ngram_range=(1,3))
X_train_dtm = vect.fit_transform(X_train)
X_test_dtm = vect.transform(X_test)
nb = MultinomialNB()
nb.fit(X_train_dtm, y_train)
y_pred_class = nb.predict(X_test_dtm)
print("Accuracy: ",metrics.accuracy_score(y_test, y_pred_class)*100)
X_train_dtm.shape
# Out:
# Accuracy:  60.48446550816219
# (28485, 591035)

# %% [markdown]
# # Sentiment Analysis

# %%
#Creating function to apply a library method to series
#-1 is most negative sentiment rank, 1 is the most positive
def detect_sentiment(tweet):
    return TextBlob(tweet).sentiment.polarity

# %%
df['sentiment_rank'] = df['text'].apply(detect_sentiment)

# %%
df.sample(n=4)
# Out:
#                     source                                               text  \
# 26174   Twitter for iPhone  Big announcement in Ames Iowa on Tuesday! You ...
# 8986   Twitter for Android  "@Michelle823: @realDonaldTrump made in China!...
# 1122    Twitter Web Client  All eyes are on Florida today. I will be watch...
# 19256  Twitter for Android  "@Cheflucky23: You have my vote and a voluntee...
#
#        retweet_count  favorite_count  is_retweet         tweet_dates  \
# 26174         2657.0          6455.0       False 2016-01-17 17:46:32
# 8986            32.0            31.0       False 2013-06-26 01:12:58
# 1122            91.0            18.0       False 2012-01-31 17:20:09
# 19256           14.0            83.0       False 2015-01-21 04:11:32
#
#        fave_count_adj engagement  sentiment_rank
# 26174        0.411382        low        0.000000
# 8986         1.722222        med       -0.182292
# 1122         0.692308        low        0.295238
# 19256        0.246657        low        0.000000

# %%
df['sentiment_rank'].describe()
# Out:
# count    37980.000000
# mean         0.184355
# std          0.357573
# min         -1.000000
# 25%          0.000000
# 50%          0.100000
# 75%          0.400000
# max          1.000000
# Name: sentiment_rank, dtype: float64

# %%
sns.distplot(df['sentiment_rank'], hist = True, kde = False);
plt.xlabel('Sentiment rank',fontsize = 20);
plt.ylabel('Frequency of tweets',fontsize = 20);

# %%
#Since the values of sentiment_rank are close to one another and somehow distributed evenly
# I made the cuts based on values -1 to 0, 0 to 0.5, 0.5 to 1
cuts = [-1, 0, 0.5, 1]
senti_category = ['negative', 'neutral', 'positive']
df['sentiment'] = pd.cut(df['sentiment_rank'].values, bins = cuts, labels = senti_category)

# %%
sns.barplot(x = df['sentiment'].value_counts().index, y = df['sentiment'].value_counts().values)

# %%
g = df.groupby(by = df["tweet_dates"].dt.year)['sentiment']
nine = g.get_group(2019)

# %%
sns.distplot(nine, hist = True)

# %%
#A function that can detect how popular a work or phrase is in the tweets 
def catch_phrase_finder(tweet):
    blob = TextBlob(tweet)
    return blob.words.count('sad')

# %%
sad = df['text'].apply(catch_phrase_finder)

# %%
df[sad.values > 0]
# Out:
#                    source                                               text  \
# 460             TweetDeck  @BarackObama is so inept that I think he simpl...
# 787             TweetDeck  He ruins the brand: @bobbeckel doesn't belong ...
# 793             TweetDeck  He ruins the brand: @Robertgbeckel doesn't bel...
# 845             TweetDeck  Why was the Hanukah celebration held in the Wh...
# 889    Twitter Web Client  With the number of tweets sad sack @Rosie has ...
# 903    Twitter Web Client  The lightweight @JonHuntsman used my name in a...
# 930    Twitter Web Client  "The sad truth is some Republicans in Congress...
# 963    Twitter Web Client  America wasted billions and precious lives in ...
# 981    Twitter Web Client  Michele Bachmann got less than 1200 more votes...
# 1104      TwitLonger Beta  “It’s sad—truly sad and disgraceful—the way Ob...
# 1727   Twitter Web Client  Now @BarackObama is praising China's "cooperat...
# 37239        28203.0        142895.0       False 2019-07-03 02:33:08
# 37410        37073.0        167607.0       False 2019-07-15 00:02:20
# 37430        29652.0        136332.0       False 2019-07-16 11:20:42
# 37627        26307.0        110596.0       False 2019-07-28 03:35:47
# 37642        17651.0         77877.0       False 2019-07-29 01:51:47
# 37646        25905.0        103049.0       False 2019-07-29 10:49:27
# 37669        18890.0         93105.0       False 2019-07-30 12:11:02
# 37793        21597.0        101847.0       False 2019-08-08 00:31:52
# 37861        13423.0         51347.0       False 2019-08-14 21:43:02
#
#        fave_count_adj engagement  sentiment_rank sentiment
# 460          0.466667        low       -0.041667  negative
# 787          0.400000        low       -0.387500  negative
# 793          0.266667        low       -0.387500  negative
# 845          1.600000        med       -0.100000  negative
# 889          9.800000       high       -0.250000  negative
# 903          0.600000        low       -0.625000  negative
# 930          0.600000        low       -0.500000  negative
# 963          1.800000        med       -0.116667  negative
# 981          0.230769        low        0.108333   neutral
# 1104         0.653846        low       -0.500000  negative
# 1727         0.192308        low       -0.500000  negative
# 1811         6.384615       high       -0.300000  negative
# 1812         0.653846        low        0.025000   neutral
# 1818         0.692308        low       -0.166667  negative
# 1960         1.384615        med       -0.500000  negative
# 2017         0.230769        low        0.062500   neutral
# 2066         0.576923        low        0.375000   neutral
# 2379         0.192308        low       -0.383333  negative
# 2419         1.423077        med        0.416667   neutral
# 2481         3.576923        med       -0.812500  negative
# 2544         0.384615        low       -0.344444  negative
# 2586         6.692308       high       -0.650000  negative
# 3329         0.653846        low       -0.312500  negative
# 3394         0.692308        low       -0.625000  negative
# 3441         1.153846        med       -0.216667  negative
# 3744         1.076923        med        0.000000  negative
# 3855         2.076923        med       -0.100000  negative
# 3877         1.653846        med       -0.750000  negative
# 4287        10.461538       high        0.312273   neutral
# 4344         2.653846        med       -0.500000  negative
# ...               ...        ...             ...       ...
# 35103        0.727542        low       -0.213571  negative
# 35129        1.816244        med       -0.197049  negative
# 35162        1.161220        med        0.130000   neutral
# 35191        0.059719        low        0.062500   neutral
# 35192        0.679950        low        0.062500   neutral
# 35396        1.110230        med       -0.170238  negative
# 35502        1.630747        med        0.058333   neutral
# 35630        1.300736        med       -0.031250  negative
# 36015        1.504142        med       -0.118679  negative
# 36239        1.311220        med       -0.169034  negative
# 36465        1.145769        med       -0.242857  negative
# 36505        0.950173        low        0.125000   neutral
# 36578        0.459800        low       -0.625000  negative
# 36581        0.910288        low        0.073052   neutral
# 36691        0.804675        low       -0.306250  negative
# 36727        1.525924        med        0.155556   neutral
# 36821        1.000801        med        0.022222   neutral
# 36869        1.123468        med       -0.393750  negative
# 36964        0.846636        low        0.136905   neutral
# 37008        0.835880        low       -0.437500  negative
# 37095        1.118525        med       -0.150000  negative
# 37239        1.612701        med       -0.431250  negative
# 37410        1.891599        med       -0.530000  negative
# 37430        1.538632        med       -0.431250  negative
# 37627        1.248177        med       -0.040741  negative
# 37642        0.878913        low       -0.052500  negative
# 37646        1.163003        med       -0.331250  negative
# 37669        1.050775        med       -0.223438  negative
# 37793        1.149437        med        0.035000   neutral
# 37861        0.579498        low       -0.625000  negative
#
# [269 rows x 10 columns]
